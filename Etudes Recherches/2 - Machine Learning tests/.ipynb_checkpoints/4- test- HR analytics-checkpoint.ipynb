# %%
# https://www.kaggle.com/arashnic/hr-analytics-job-change-of-data-scientists?select=aug_train.csv  -- context and content



# Notes:
    # pd.cut...  (pour créer des tranches d'âge par exemple)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\elbakkali\Desktop\Datasets_Machine_Learning\aug_train.csv', sep=',')

# %%
df2 = df.copy()

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
df.shape
# Out:
# (19158, 14)

# %%
df.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# last_new_job               423
# training_hours               0
# target                       0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.nunique()
# Out:
# enrollee_id               19158
# city                        123
# city_development_index       93
# gender                        3
# relevent_experience           2
# enrolled_university           3
# education_level               5
# major_discipline              6
# experience                   22
# company_size                  8
# company_type                  6
# last_new_job                  6
# training_hours              241
# target                        2
# dtype: int64

# %%
df['target'].value_counts()/df['target'].value_counts().sum()
# Out:
# 0.0    0.750652
# 1.0    0.249348
# Name: target, dtype: float64

# %%
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

# %%
df_gender = df[df['gender'].notna()]

# %%
df_no_na = df.dropna()

# %%
df_no_na.shape
# Out:
# (8955, 14)

# %% [markdown]
# # plotly.py
#
# Welcome to Plotly forum!!!
# Before working with plotly express you should have some background in plotly.py.
#
# A figure consists in data, and layout (while animations have also, frames). Data is a list of traces such as
# scatter, bar, heatmap, etc Each trace has a few attributes that can be updated after your fig was defined.
#
# As long as you have no knowledge on plotly.py you are not able to update your figures according to your preferences.
#
# In the case of your code above you should perform the following update:
#
# fig.update_traces(marker_color='green')
# To get info on Bar attributes just type:
#
# help(go.Bar)
# and similarly on any trace type.
# To update the figure appearance (i.e to improve its aesthetics) you can update its layout. Just try it for your example:
#
# fig.update_layout(width=700, height=500, bargap=0.05)

# %%
#for col in df_no_na.select_dtypes(object):    
fig.update_traces(marker_color='red')
fig.update_traces(marker_color='green')
fig = px.bar(df_no_na, x='education_level', facet_row='target', color='gender', 
            color_discrete_map={
        'Male'  : 'blue',
        'Female': 'red',
        'Other' :'green' })#, pattern_shape='gender', pattern_shape_sequence=[".", "x", "+"])
fig.show()
# Out:
# <div>                            <div id="5d8631f6-80f3-48df-8338-8ab072152a99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d8631f6-80f3-48df-8338-8ab072152a99")) {                    Plotly.newPlot(                        "5d8631f6-80f3-48df-8338-8ab072152a99",                        [{"alignmentgroup":"True","hovertemplate":"gender=Male<br>target=0.0<br>education_level=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Male","marker":{"color":"blue","pattern":{"shape":""}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["Graduate","Masters","Graduate","Graduate","Graduate","Masters","Masters","Graduate","Graduate","Graduate","Graduate","Graduate","Graduate","Graduate","Graduate","G
# ...

# %%
fig = px.bar(df, x='company_size', y='training_hours')
fig.show()
# Out:
# <div>                            <div id="0e160244-f062-4bec-98b4-71e003c0eb7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e160244-f062-4bec-98b4-71e003c0eb7f")) {                    Plotly.newPlot(                        "0e160244-f062-4bec-98b4-71e003c0eb7f",                        [{"alignmentgroup":"True","hovertemplate":"company_size=%{x}<br>training_hours=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":[null,"50-99",null,null,"50-99",null,"50-99","<10","50-99","10000+",null,"5000-9999","1000-4999",null,null,"10/49","50-99","5000-9999","10000+",null,"100-500","100-500",null,"1000-4999","1000-4999
# ...

# %%
df.groupby(['company_size']).mean().sort_values(['training_hours'], ascending=False)
# Out:
#                enrollee_id  city_development_index  training_hours    target
# company_size
# 50-99         16608.084982                0.829356       68.163801  0.176776
# 10/49         16925.460911                0.813927       66.925901  0.233855
# <10           16382.646789                0.824622       65.801988  0.171254
# 1000-4999     16716.554970                0.857128       64.621235  0.150602
# 5000-9999     17127.014210                0.849064       64.543517  0.181172
# 10000+        17143.857355                0.846206       64.523526  0.190688
# 500-999       16424.604333                0.836881       64.282782  0.173318
# 100-500       16421.241540                0.835129       63.984442  0.161416

# %%
sns.distplot(df['training_hours'])
# Out:
# C:\Users\elbakkali\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='training_hours', ylabel='Density'>

# %%
sns.distplot(df['city_development_index'])
# Out:
# C:\Users\elbakkali\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='city_development_index', ylabel='Density'>

# %%
sns.heatmap(pd.crosstab(index=df['gender'] ,columns=df['education_level']))
# Out:
# <AxesSubplot:xlabel='education_level', ylabel='gender'>

# %%
gender_education_level = pd.crosstab(index=df['gender'] ,columns=df['education_level'], margins=True, margins_name='Total')

# %%
df['training_hours'].groupby(df['gender']).mean()
# Out:
# gender
# Female    65.636511
# Male      65.297633
# Other     63.869110
# Name: training_hours, dtype: float64

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.nunique()
# Out:
# enrollee_id               19158
# city                        123
# city_development_index       93
# gender                        3
# relevent_experience           2
# enrolled_university           3
# education_level               5
# major_discipline              6
# experience                   22
# company_size                  8
# company_type                  6
# last_new_job                  6
# training_hours              241
# target                        2
# dtype: int64

# %%
df['relevent_experience']= df['relevent_experience'].replace('Has relevent experience', 1)
df['relevent_experience']= df['relevent_experience'].replace('No relevent experience', 0)

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  relevent_experience  \
# 0         8949  city_103                   0.920   Male                    1
# 1        29725   city_40                   0.776   Male                    0
# 2        11561   city_21                   0.624    NaN                    0
# 3        33241  city_115                   0.789    NaN                    0
# 4          666  city_162                   0.767   Male                    1
#
#   enrolled_university education_level major_discipline experience  \
# 0       no_enrollment        Graduate             STEM        >20
# 1       no_enrollment        Graduate             STEM         15
# 2    Full time course        Graduate             STEM          5
# 3                 NaN        Graduate  Business Degree         <1
# 4       no_enrollment         Masters             STEM        >20
#
#   company_size    company_type last_new_job  training_hours  target
# ...

# %%
df_gender= df[df['gender'].notna()]

# %%
df_gender.head()
# Out:
#    enrollee_id      city  city_development_index gender  relevent_experience  \
# 0         8949  city_103                   0.920   Male                    1
# 1        29725   city_40                   0.776   Male                    0
# 4          666  city_162                   0.767   Male                    1
# 6        28806  city_160                   0.920   Male                    1
# 7          402   city_46                   0.762   Male                    1
#
#   enrolled_university education_level major_discipline experience  \
# 0       no_enrollment        Graduate             STEM        >20
# 1       no_enrollment        Graduate             STEM         15
# 4       no_enrollment         Masters             STEM        >20
# 6       no_enrollment     High School              NaN          5
# 7       no_enrollment        Graduate             STEM         13
#
#   company_size    company_type last_new_job  training_hours  target
# ...

# %%
df_gender['target'].value_counts(normalize=True)
# Out:
# 0.0    0.768737
# 1.0    0.231263
# Name: target, dtype: float64

# %%
df_gender.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index       0
# gender                       0
# relevent_experience          0
# enrolled_university        213
# education_level            259
# major_discipline          1978
# experience                  16
# company_size              4313
# company_type              4433
# last_new_job                74
# training_hours               0
# target                       0
# dtype: int64

# %%
df_gender['company_size'].value_counts()
# Out:
# 50-99        2362
# 100-500      2070
# 10000+       1584
# 10/49        1141
# 1000-4999    1050
# <10          1001
# 500-999       680
# 5000-9999     449
# Name: company_size, dtype: int64

# %%
df_gender['company_size'] = df_gender['company_size'].replace(['<10','10/49' ], '0-49')
df_gender['company_size'] = df_gender['company_size'].replace(['50-99', '100-500'], '50-500')
df_gender['company_size'] = df_gender['company_size'].replace(['500-999', '1000-4999', '5000-9999', '10000+'], '500+')
# Out:
# C:\Users\ELBAKK~1\AppData\Local\Temp/ipykernel_11812/471492950.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ELBAKK~1\AppData\Local\Temp/ipykernel_11812/471492950.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ELBAKK~1\AppData\Local\Temp/ipykernel_11812/471492950.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_gender['company_size'].value_counts()
# Out:
# 50-500    4432
# 500+      3763
# 0-49      2142
# Name: company_size, dtype: int64

# %%
df_gender.nunique()
# Out:
# enrollee_id               14650
# city                        122
# city_development_index       92
# gender                        3
# relevent_experience           2
# enrolled_university           3
# education_level               5
# major_discipline              6
# experience                   22
# company_size                  3
# company_type                  6
# last_new_job                  6
# training_hours              241
# target                        2
# dtype: int64

# %%
df_gender.drop('city', axis= 1 , inplace=True)
# Out:
# C:\Users\elbakkali\anaconda3\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_gender.head()
# Out:
#    enrollee_id  city_development_index gender  relevent_experience  \
# 0         8949                   0.920   Male                    1
# 1        29725                   0.776   Male                    0
# 4          666                   0.767   Male                    1
# 6        28806                   0.920   Male                    1
# 7          402                   0.762   Male                    1
#
#   enrolled_university education_level major_discipline experience  \
# 0       no_enrollment        Graduate             STEM        >20
# 1       no_enrollment        Graduate             STEM         15
# 4       no_enrollment         Masters             STEM        >20
# 6       no_enrollment     High School              NaN          5
# 7       no_enrollment        Graduate             STEM         13
#
#   company_size    company_type last_new_job  training_hours  target
# 0          NaN             NaN            1              36     1.0
# ...

# %%
df_gender.isna().sum()
# Out:
# enrollee_id                  0
# city_development_index       0
# gender                       0
# relevent_experience          0
# enrolled_university        213
# education_level            259
# major_discipline          1978
# experience                  16
# company_size              4313
# company_type              4433
# last_new_job                74
# training_hours               0
# target                       0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
df_gender['company_type'].value_counts()
# Out:
# Pvt Ltd                7728
# Funded Startup          846
# Public Sector           716
# Early Stage Startup     431
# NGO                     404
# Other                    92
# Name: company_type, dtype: int64

# %%
simp = SimpleImputer(strategy='most_frequent')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\ELBAKK~1\AppData\Local\Temp/ipykernel_11812/4279590704.py in <module>
# ----> 1 pd.DataFrame( simp.fit_transform(df[['company_type']]), index= df['company_type'].index , columns='company_type')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     318
#     319     # _prep_ndarray ensures that values.ndim == 2 at this point
# --> 320     index, columns = _get_axes(
#     321         values.shape[0], values.shape[1], index=index, columns=columns
# ...
