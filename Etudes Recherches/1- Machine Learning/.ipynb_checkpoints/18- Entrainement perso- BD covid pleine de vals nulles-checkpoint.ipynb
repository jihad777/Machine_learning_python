# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel(r'C:\Users\elbakkali\Desktop\Datasets_Machine_Learning\dataset.xlsx')

# %%
data.head()
# Out:
#         Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 0  44477f75e8169d2                    13               negative
# 1  126e9dd13932f68                    17               negative
# 2  a46b4402a0e5696                     8               negative
# 3  f7d619a94f97c45                     5               negative
# 4  d9e41465789c2b5                    15               negative
#
#    Patient addmited to regular ward (1=yes, 0=no)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
data.drop(['Patient ID'], axis= 1)
data.describe()
# Out:
#        Patient age quantile  Patient addmited to regular ward (1=yes, 0=no)  \
# count           5644.000000                                     5644.000000
# mean               9.318391                                        0.013997
# std                5.777903                                        0.117489
# min                0.000000                                        0.000000
# 25%                4.000000                                        0.000000
# 50%                9.000000                                        0.000000
# 75%               14.000000                                        0.000000
# max               19.000000                                        1.000000
#
#        Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# count                                        5644.000000
# mean                                            0.008859
# std                                             0.093713
# ...

# %%
data.columns
# Out:
# Index(['Patient ID', 'Patient age quantile', 'SARS-Cov-2 exam result',
#        'Patient addmited to regular ward (1=yes, 0=no)',
#        'Patient addmited to semi-intensive unit (1=yes, 0=no)',
#        'Patient addmited to intensive care unit (1=yes, 0=no)', 'Hematocrit',
#        'Hemoglobin', 'Platelets', 'Mean platelet volume ',
#        ...
#        'Hb saturation (arterial blood gases)',
#        'pCO2 (arterial blood gas analysis)',
#        'Base excess (arterial blood gas analysis)',
#        'pH (arterial blood gas analysis)',
#        'Total CO2 (arterial blood gas analysis)',
#        'HCO3 (arterial blood gas analysis)',
#        'pO2 (arterial blood gas analysis)', 'Arteiral Fio2', 'Phosphor',
#        'ctO2 (arterial blood gas analysis)'],
#       dtype='object', length=111)

# %%
covid_positive = data[data['SARS-Cov-2 exam result'] == 'positive']
covid_negative = data[data['SARS-Cov-2 exam result'] == 'negative']

# %%
covid_positive.head()
# Out:
#           Patient ID  Patient age quantile SARS-Cov-2 exam result  \
# 67   78511c183ae18bc                     7               positive
# 284  d7834ed75f2da44                    16               positive
# 513  b16b49f7bd3e692                    10               positive
# 568  4382f5ea05e60c4                     2               positive
# 676  d3729cd2658ca64                    15               positive
#
#      Patient addmited to regular ward (1=yes, 0=no)  \
# 67                                                0
# 284                                               1
# 513                                               0
# 568                                               0
# 676                                               0
#
#      Patient addmited to semi-intensive unit (1=yes, 0=no)  \
# 67                                                   0
# 284                                                  0
# 513                                                  0
# ...

# %%
data.drop(['Hb saturation (arterial blood gases)',])
