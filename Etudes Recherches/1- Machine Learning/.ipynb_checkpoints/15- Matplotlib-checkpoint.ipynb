# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

x = iris.data
y = iris.target
names = list(iris.target_names)

print(f'x contient {x.shape[0]} exemples et {x.shape[1]} variables')
print(f'il y a {np.unique(y).size} classes')
# Out:
# x contient 150 exemples et 4 variables
# il y a 3 classes

# %%
#Nuage de points personnalisés
plt.scatter(x[:,0], x[:,1], c=y, alpha=1.5, s=x[:,2]*100) #c=y pour colorier les diff points du nuage selon la classe de y
                                                          #alpha = contraste
                                                          #s = taille des points, ici selon la troisième variable de notre DTset
plt.xlabel('longeur sépal')
plt.ylabel('largeur sépal')
# Out:
# Text(0, 0.5, 'largeur sépal')

# %%
#-----------Graphique 3D---------------
#pour pouvoir zoomer/dézoomer retourner le graph 3D 

from mpl_toolkits.mplot3d import Axes3D
# Out:
# Using matplotlib backend: Qt5Agg

# %%
plt.figure(figsize=(10,8))
ax = plt.axes(projection='3d')
ax.scatter(x[:,0],x[:,1], x[:,2], c=y )

# %%
#--------------Histogramme-------------
#Extrêmement utile en stats et ML pour savoir la distribution d'une variable et si elle suit une loi normale
plt.hist(x[:,0], bins=30)
plt.hist(x[:,1], bins= 2)
# Out:
# (array([94., 56.]), array([2. , 3.2, 4.4]), <BarContainer object of 2 artists>)

# %%
#histogramme 2D
plt.hist2d(x[:,0],x[:,1], cmap='Blues')
plt.xlabel('longeur sépal')
plt.ylabel('largeur sépal')
plt.colorbar()  #color bar pour afficher la fréquence

# %%
#---------------Contour plot----------------- ML = résoudre des problèmes d'optimisation 
#                                             (par ex: minimiser la fonction cout, maximiser les revenus....)
f = lambda x,y : np.sin(x)+ np.cos(x+y)
X = np.linspace(0,5,100)
Y = np.linspace(0,5,100)
X,Y = np.meshgrid(X,Y)
Z = f(X,Y)

# %%
plt.contour(X,Y,Z, 20, colors='black') #ligne continues = valeurs positives (max) / tirés = valeurs négatives (min)

# %%
plt.contourf(X,Y,Z,20,cmap='Blues')
plt.colorbar()
#avec ça on peut comprendre quelles sont les valeurs de notre gradient sur notre contour-plot
